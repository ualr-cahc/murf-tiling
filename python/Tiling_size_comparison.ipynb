# %%
import os
from tileTools.makeTiles import makeTiles

# %%
raw_inputs = "d:/Metroplan Files Renamed/"
input_filenames = ["1960_Metro_Area_Office_and_Commercial_Uses", "1970s_LITRK-NOLIT_SMSA_Industrial", "1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25"]
base_output_dir = "d:/murf-tiling/tests/zoom_levels/"
translate_output_dir = os.path.join(base_output_dir, "translated")
input_filepaths = [os.path.join(raw_inputs, input_filename)+".tif" for input_filename in input_filenames]
output_params = [[os.path.join(base_output_dir, f"zoom{x}"), {"nb_processes": 8, "zoom": (x,x), "resume": True, "webviewer": "leaflet"}] for x in range(8, 21)]
print(output_params, "\n", input_filepaths, "\n", translate_output_dir)
# Out:
# [['d:/murf-tiling/tests/zoom_levels/zoom8', {'nb_processes': 8, 'zoom': (8, 8), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom9', {'nb_processes': 8, 'zoom': (9, 9), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom10', {'nb_processes': 8, 'zoom': (10, 10), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom11', {'nb_processes': 8, 'zoom': (11, 11), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom12', {'nb_processes': 8, 'zoom': (12, 12), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom13', {'nb_processes': 8, 'zoom': (13, 13), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom14', {'nb_processes': 8, 'zoom': (14, 14), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom15', {'nb_processes': 8, 'zoom': (15, 15), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom16', {'nb_processes': 8, 'zoom': (16, 16), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom17', {'nb_processes': 8, 'zoom': (17, 17), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom18', {'nb_processes': 8, 'zoom': (18, 18), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom19', {'nb_processes': 8, 'zoom': (19, 19), 'resume': True, 'webviewer': 'leaflet'}], ['d:/murf-tiling/tests/zoom_levels/zoom20', {'nb_processes': 8, 'zoom': (20, 20), 'resume': True, 'webviewer': 'leaflet'}]]
#  ['d:/Metroplan Files Renamed/1960_Metro_Area_Office_and_Commercial_Uses.tif', 'd:/Metroplan Files Renamed/1970s_LITRK-NOLIT_SMSA_Industrial.tif', 'd:/Metroplan Files Renamed/1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif']
#  d:/murf-tiling/tests/zoom_levels/translated

# %%
for tile_output_dir, tile_options in output_params:
    print(f"makeTiles({raw_inputs, tile_output_dir, translate_output_dir, tile_options})")
    makeTiles(input_filepaths, tile_output_dir, translate_output_dir, tile_options)
    print
    print("---------------------------------------------------------------------")
    print()
# Out:
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom8', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (8, 8), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (8, 8)
# Tile time: 0.0m 3s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (8, 8)
# Tile time: 0.0m 1s
# d:/murf-tiling/tests/zoom_levels/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif (8, 8)
# Tile time: 0.0m 2s
# makeTiles time 0.0m 6s
# ---------------------------------------------------------------------
#
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom9', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (9, 9), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (9, 9)
# Tile time: 0.0m 3s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (9, 9)
# Tile time: 0.0m 1s
# d:/murf-tiling/tests/zoom_levels/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif (9, 9)
# Tile time: 0.0m 2s
# makeTiles time 0.0m 6s
# ---------------------------------------------------------------------
#
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom10', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (10, 10), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (10, 10)
# Tile time: 0.0m 3s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (10, 10)
# Tile time: 0.0m 1s
# d:/murf-tiling/tests/zoom_levels/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif (10, 10)
# Tile time: 0.0m 2s
# makeTiles time 0.0m 6s
# ---------------------------------------------------------------------
#
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom11', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (11, 11), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (11, 11)
# Tile time: 0.0m 3s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (11, 11)
# Tile time: 0.0m 1s
# d:/murf-tiling/tests/zoom_levels/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif (11, 11)
# Tile time: 0.0m 2s
# makeTiles time 0.0m 6s
# ---------------------------------------------------------------------
#
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom12', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (12, 12), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (12, 12)
# Tile time: 0.0m 2s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (12, 12)
# Tile time: 0.0m 1s
# d:/murf-tiling/tests/zoom_levels/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif (12, 12)
# Tile time: 0.0m 1s
# makeTiles time 0.0m 5s
# ---------------------------------------------------------------------
#
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom13', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (13, 13), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (13, 13)
# Tile time: 0.0m 3s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (13, 13)
# Tile time: 0.0m 1s
# d:/murf-tiling/tests/zoom_levels/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif (13, 13)
# Tile time: 0.0m 2s
# makeTiles time 0.0m 5s
# ---------------------------------------------------------------------
#
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom14', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (14, 14), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (14, 14)
# Tile time: 0.0m 3s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (14, 14)
# Tile time: 0.0m 1s
# d:/murf-tiling/tests/zoom_levels/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif (14, 14)
# Tile time: 0.0m 1s
# makeTiles time 0.0m 5s
# ---------------------------------------------------------------------
#
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom15', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (15, 15), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (15, 15)
# Tile time: 0.0m 3s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (15, 15)
# Tile time: 0.0m 2s
# d:/murf-tiling/tests/zoom_levels/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif (15, 15)
# Tile time: 0.0m 1s
# makeTiles time 0.0m 6s
# ---------------------------------------------------------------------
#
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom16', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (16, 16), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (16, 16)
# Tile time: 0.0m 2s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (16, 16)
# Tile time: 0.0m 3s
# d:/murf-tiling/tests/zoom_levels/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif (16, 16)
# Tile time: 0.0m 1s
# makeTiles time 0.0m 7s
# ---------------------------------------------------------------------
#
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom17', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (17, 17), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (17, 17)
# Tile time: 0.0m 3s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (17, 17)
# Tile time: 13.0m 15s
# d:/murf-tiling/tests/zoom_levels/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif (17, 17)
# Tile time: 0.0m 2s
# makeTiles time 13.0m 21s
# ---------------------------------------------------------------------
#
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom18', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (18, 18), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (18, 18)
# Tile time: 5.0m 32s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (18, 18)
# Tile time: 60.0m 39s
# d:/murf-tiling/tests/zoom_levels/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif (18, 18)
# Tile time: 0.0m 4s
# makeTiles time 66.0m 15s
# ---------------------------------------------------------------------
#
# makeTiles(('d:/Metroplan Files Renamed/', 'd:/murf-tiling/tests/zoom_levels/zoom19', 'd:/murf-tiling/tests/zoom_levels/translated', {'nb_processes': 8, 'zoom': (19, 19), 'resume': True, 'webviewer': 'leaflet'}))
# translate2bytes time 0.0m 0s
# d:/murf-tiling/tests/zoom_levels/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif (19, 19)
# Tile time: 17.0m 56s
# d:/murf-tiling/tests/zoom_levels/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif (19, 19)

# %%
raw_inputs = "d:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/"
input_filenames = ["1960_Metro_Area_Office_and_Commercial_Uses", "1970s_LITRK-NOLIT_SMSA_Industrial", "1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25"]
base_output_dir = "d:/ualr-cahc/murf-tiling/tests/timer_test/"
translate_output_dir = os.path.join(base_output_dir, "translated")
tile_output_dir = os.path.join(base_output_dir, "tiles")
input_filepaths = [os.path.join(raw_inputs, input_filename)+".tif" for input_filename in input_filenames]
zoom = [8, 25]
tile_options = {"nb_processes": 8, "zoom": zoom, "webviewer": 'none'}
makeTiles(input_filepaths, tile_output_dir, translate_output_dir, tile_options)
# Out:
# makeTiles(((['d:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1960_Metro_Area_Office_and_Commercial_Uses.tif', 'd:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1970s_LITRK-NOLIT_SMSA_Industrial.tif', 'd:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif'], 'd:/ualr-cahc/murf-tiling/tests/timer_test/tiles', 'd:/ualr-cahc/murf-tiling/tests/timer_test/translated', {'nb_processes': 8, 'zoom': [8, 25]}), {}))
# translate2bytes(((['d:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1960_Metro_Area_Office_and_Commercial_Uses.tif', 'd:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1970s_LITRK-NOLIT_SMSA_Industrial.tif', 'd:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif'], 'd:/ualr-cahc/murf-tiling/tests/timer_test/translated'), {}))
# translate2bytes time 0.0m 13s
# ---------------------------------------------------------------------
#
# zoom: 8 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 4s
#
# ---------------------------------------------------------------------
#
# zoom: 9 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 3s
#
# ---------------------------------------------------------------------
#
# zoom: 10 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 3s
#
# ---------------------------------------------------------------------
#
# zoom: 11 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 3s
#
# ---------------------------------------------------------------------
#
# zoom: 12 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 4s
#
# ---------------------------------------------------------------------
#
# zoom: 13 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 5s
#
# ---------------------------------------------------------------------
#
# zoom: 14 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 8s
#
# ---------------------------------------------------------------------
#
# zoom: 15 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 17s
#
# ---------------------------------------------------------------------
#
# zoom: 16 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 53s
#
# ---------------------------------------------------------------------
#
# zoom: 17 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 1.0m 60s
#
# ---------------------------------------------------------------------
#
# zoom: 8 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 9 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 10 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 11 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 12 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 3s
#
# ---------------------------------------------------------------------
#
# zoom: 13 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 13s
#
# ---------------------------------------------------------------------
#
# zoom: 14 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 22s
#
# ---------------------------------------------------------------------
#
# zoom: 15 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 1.0m 14s
#
# ---------------------------------------------------------------------
#
# zoom: 8 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 9 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 10 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 11 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 12 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 13 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 14 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 15 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 16 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 17 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 18 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 19 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 20 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 3s
#
# ---------------------------------------------------------------------
#
# zoom: 21 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 3s
#
# ---------------------------------------------------------------------
#
# zoom: 22 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 5s
#
# ---------------------------------------------------------------------
#
# zoom: 23 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 11s
#
# ---------------------------------------------------------------------
#
# zoom: 24 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 32s
#
# ---------------------------------------------------------------------
#
# zoom: 25 for d:/ualr-cahc/murf-tiling/tests/timer_test/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 1.0m 21s
#
# ---------------------------------------------------------------------
#
# makeTiles time 8.0m 31s
# ---------------------------------------------------------------------

# %%
raw_inputs = "d:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/"
input_filenames = ["1960_Metro_Area_Office_and_Commercial_Uses", "1970s_LITRK-NOLIT_SMSA_Industrial", "1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25"]
base_output_dir = "d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/"
translate_output_dir = os.path.join(base_output_dir, "translated")
tile_output_dir = os.path.join(base_output_dir, "tiles")
input_filepaths = [os.path.join(raw_inputs, input_filename)+".tif" for input_filename in input_filenames]
zoom = [8, 25]
tile_options = {"nb_processes": 8, "zoom": zoom, "webviewer": 'none'}
makeTiles(input_filepaths, tile_output_dir, translate_output_dir, tile_options, "writeLeaflet_test")
# Out:
# makeTiles(((['d:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1960_Metro_Area_Office_and_Commercial_Uses.tif', 'd:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1970s_LITRK-NOLIT_SMSA_Industrial.tif', 'd:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif'], 'd:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/tiles', 'd:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated', {'nb_processes': 8, 'zoom': [8, 25], 'webviewer': 'none'}, 'writeLeaflet_test'), {}))
# translate2bytes(((['d:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1960_Metro_Area_Office_and_Commercial_Uses.tif', 'd:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1970s_LITRK-NOLIT_SMSA_Industrial.tif', 'd:/ualr-cahc/murf-tiling/TIFFs/GeoTIFFs/Metroplan Files Renamed/1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif'], 'd:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated'), {}))
# translate2bytes time 0.0m 0s
# zoom: 8 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 4s
#
# ---------------------------------------------------------------------
#
# zoom: 9 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 4s
#
# ---------------------------------------------------------------------
#
# zoom: 10 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 4s
#
# ---------------------------------------------------------------------
#
# zoom: 11 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 4s
#
# ---------------------------------------------------------------------
#
# zoom: 12 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 4s
#
# ---------------------------------------------------------------------
#
# zoom: 13 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 4s
#
# ---------------------------------------------------------------------
#
# zoom: 14 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 4s
#
# ---------------------------------------------------------------------
#
# zoom: 15 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 0.0m 3s
#
# ---------------------------------------------------------------------
#
# zoom: 16 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1960_Metro_Area_Office_and_Commercial_Uses.tif
# Tile time: 1.0m 10s
#
# ---------------------------------------------------------------------
#
# zoom: 8 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 9 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 10 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 11 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 12 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 13 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 14 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 0.0m 33s
#
# ---------------------------------------------------------------------
#
# zoom: 15 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1970s_LITRK-NOLIT_SMSA_Industrial.tif
# Tile time: 1.0m 23s
#
# ---------------------------------------------------------------------
#
# zoom: 8 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 5s
#
# ---------------------------------------------------------------------
#
# zoom: 9 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 10 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 11 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 12 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 13 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 14 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 15 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 16 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 17 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 18 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 19 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 20 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 21 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 22 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 23 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 2s
#
# ---------------------------------------------------------------------
#
# zoom: 24 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 0.0m 39s
#
# ---------------------------------------------------------------------
#
# zoom: 25 for d:/ualr-cahc/murf-tiling/tests/timer_test_with_writeLeaflet/translated\1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif
# Tile time: 1.0m 51s
#
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\ualr-cahc\murf-tiling\python\Tiling_size_comparison.ipynb Cell 3' in <cell line: 9>()
#       <a href='vscode-notebook-cell:/d%3A/ualr-cahc/murf-tiling/python/Tiling_size_comparison.ipynb#ch0000002?line=6'>7</a> zoom = [8, 25]
#       <a href='vscode-notebook-cell:/d%3A/ualr-cahc/murf-tiling/python/Tiling_size_comparison.ipynb#ch0000002?line=7'>8</a> tile_options = {"nb_processes": 8, "zoom": zoom, "webviewer": 'none'}
# ----> <a href='vscode-notebook-cell:/d%3A/ualr-cahc/murf-tiling/python/Tiling_size_comparison.ipynb#ch0000002?line=8'>9</a> makeTiles(input_filepaths, tile_output_dir, translate_output_dir, tile_options, "writeLeaflet_test")
#
# File d:\ualr-cahc\murf-tiling\python\tileTools\calcTime.py:8, in calcTime.<locals>.inner1(*args, **kwargs)
#       6 print(f"{func.__name__}({args, kwargs})")
#       7 begin = perf_counter()
# ----> 8 func(*args, **kwargs)
#       9 end = perf_counter()
#      10 time = end-begin
#
# File d:\ualr-cahc\murf-tiling\python\tileTools\makeTiles.py:49, in makeTiles(input_filepaths, tile_output_dir, translate_output_dir, tile_options, title)
#      47         print("---------------------------------------------------------------------")
#      48         print()
# ---> 49 leaflet_text = writeLeaflet(layers, max(layers.values()), title)
#      50 with open(os.path.join(tile_output_dir, "leaflet.html"), 'w') as file:
#      51     file.write(leaflet_text)
#
# File d:\ualr-cahc\murf-tiling\python\tileTools\writeLeaflet.py:2, in writeLeaflet(layers, maxZoom, title)
#       1 def writeLeaflet(layers: dict[str, int], maxZoom: int, title: str) -> str:
# ----> 2     text = """<!DOCTYPE html>
#       3             <html lang="en">
#       4             <head>
#       5                 <meta charset="utf-8">
#       6                 <meta name='viewport' content='width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no' />
#       7                 <title>1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25.tif</title>
#       8
#       9                 <!-- Leaflet -->
#      10                 <link rel="stylesheet" href="http://cdn.leafletjs.com/leaflet-0.7.5/leaflet.css" />
#      11                 <script src="http://cdn.leafletjs.com/leaflet-0.7.5/leaflet.js"></script>
#      12
#      13                 <style>
#      14                     body { margin:0; padding:0; }
#      15                     body, table, tr, td, th, div, h1, h2, input { font-family: "Calibri", "Trebuchet MS", "Ubuntu", Serif; font-size: 11pt; }
#      16                     #map { position:absolute; top:0; bottom:0; width:100%; } /* full size */
#      17                     .ctl {
#      18                         padding: 2px 10px 2px 10px;
#      19                         background: white;
#      20                         background: rgba(255,255,255,0.9);
#      21                         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#      22                         border-radius: 5px;
#      23                         text-align: right;
#      24                     }
#      25                     .title {
#      26                         font-size: 18pt;
#      27                         font-weight: bold;
#      28                     }
#      29                     .src {
#      30                         font-size: 10pt;
#      31                     }
#      32
#      33                 </style>
#      34
#      35             </head>
#      36             <body>
#      37
#      38             <div id="map"></div>
#      39
#      40             <script>
#      41             /* **** Leaflet **** */
#      42
#      43             // Base layers
#      44             //  .. OpenStreetMap
#      45             var osm = L.tileLayer('http://{s}.tile.osm.org/{z}/{x}/{y}.png', {attribution: '&copy; <a href="http://osm.org/copyright">OpenStreetMap</a> contributors'});
#      46
#      47             // Overlay layers (TMS)
#      48             """ + "\n            ".join(f"var {name} = L.tileLayer('./{name}/{{z}}/{{x}}/{{y}}.png', {{tms: true, opacity: 0.7, attribution: '', maxZoom:{maxZoom}, maxNativeZoom: {maxNativeZoom}}});" for name, maxNativeZoom in layers.items())+"""
#      49
#      50             // Map
#      51             var map = L.map('map', {
#      52                 center: [34.773076232375914, -92.42107092780141],
#      53                 zoom: 8,
#      54                 maxZoom: """ + maxZoom + """,
#      55                 layers: [osm]
#      56             });
#      57
#      58             var basemaps = {"OpenStreetMap": osm}
#      59             var overlaymaps = {
#      60                 """ + "\n                ".join(f'"{name}": {name},' for name in layers) + """
#      61             }
#      62             // Title
#      63             var title = L.control();
#      64             title.onAdd = function(map) {
#      65                 this._div = L.DomUtil.create('div', 'ctl title');
#      66                 this.update();
#      67                 return this._div;
#      68             };
#      69             title.update = function(props) {
#      70                 this._div.innerHTML = '""" + title + """';
#      71             };
#      72             title.addTo(map);
#      73
#      74             // Note
#      75             var src = 'Generated by <a href="http://www.klokan.cz/projects/gdal2tiles/">GDAL2Tiles</a>, Copyright &copy; 2008 <a href="http://www.klokan.cz/">Klokan Petr Pridal</a>,  <a href="http://www.gdal.org/">GDAL</a> &amp; <a href="http://www.osgeo.org/">OSGeo</a> <a href="http://code.google.com/soc/">GSoC</a>';
#      76             var title = L.control{(position: 'bottomleft'});
#      77             title.onAdd = function(map) {
#      78                 this._div = L.DomUtil.create('div', 'ctl src');
#      79                 this.update();
#      80                 return this._div;
#      81             };
#      82             title.update = function(props) {
#      83                 this._div.innerHTML = src;
#      84             };
#      85             title.addTo(map);
#      86
#      87
#      88             // Add base layers
#      89             L.control.layers(basemaps, overlaymaps, {collapsed: false}).addTo(map);
#      90
#      91             // Fit to overlay bounds (SW and NE points with (lat, lon))
#      92             // map.fitBounds([[34.77259443119747, -92.42051045688615], [34.773558033554366, -92.42163139871667]]);
#      93
#      94             </script>
#      95
#      96             </body>
#      97             </html>"""
#      98     return text
#
# TypeError: can only concatenate str (not "int") to str

# %%
from tileTools.writeLeaflet import writeLeaflet

layers = {
    "1960_Metro_Area_Office_and_Commercial_Uses": 16,
    "1970s_LITRK-NOLIT_SMSA_Industrial": 15,
    "1998_AHTD_060772_LITRK_Hinson_Rd_Sidewalks_25": 25,
}

leaflet_text = writeLeaflet(layers, max(layers.values()), "writeLeaflet_test")

# %%
with open(r"D:\ualr-cahc\murf-tiling\tests\timer_test_with_writeLeaflet\tiles\writeLeaflet_test.html", "w") as file:
    file.write(leaflet_text)
